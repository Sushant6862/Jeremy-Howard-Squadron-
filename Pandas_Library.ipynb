# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushant6862/Jeremy-Howard-Squadron-/blob/main/Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Please explore the nba.csv dataset and perform EDA.Get the insights out of it.

# %%
import pandas as pd

# making data frame
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nba.csv")

# calling head() method
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.tail()
# By default it will take last 5 rows
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
data.tail(15)
#  last 15 records
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445      Dante Exum  Utah Jazz    11.0       PG  20.0    6-6   190.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0   6-10   265.0
# 447     Rudy Gobert  Utah Jazz    27.0        C  23.0    7-1   245.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# ...

# %%
data.info()
# How many entries that table content
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.nunique()
# Out:
# Name        457
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %% [markdown]
# ### Dealing with Rows and Columns in Pandas DataFrame:

# %%
df = pd.DataFrame(data)
print(df[["Name","Team","Age","Weight"]])
# Out:
#               Name            Team   Age  Weight
# 0    Avery Bradley  Boston Celtics  25.0   180.0
# 1      Jae Crowder  Boston Celtics  25.0   235.0
# 2     John Holland  Boston Celtics  27.0   205.0
# 3      R.J. Hunter  Boston Celtics  22.0   185.0
# 4    Jonas Jerebko  Boston Celtics  29.0   231.0
# ..             ...             ...   ...     ...
# 453   Shelvin Mack       Utah Jazz  26.0   203.0
# 454      Raul Neto       Utah Jazz  24.0   179.0
# 455   Tibor Pleiss       Utah Jazz  26.0   256.0
# 456    Jeff Withey       Utah Jazz  26.0   231.0
# 457            NaN             NaN   NaN     NaN
#
# [458 rows x 4 columns]

# %%
df.corr()
# Out:
# <ipython-input-19-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Number       Age    Weight    Salary
# Number  1.000000  0.028724  0.206921 -0.112386
# Age     0.028724  1.000000  0.087183  0.213459
# Weight  0.206921  0.087183  1.000000  0.138321
# Salary -0.112386  0.213459  0.138321  1.000000

# %%
data.drop(["Team", "Weight"], axis = 1, inplace = True)

# %%
print(data)
# Out:
#               Name  Number Position   Age Height            College     Salary
# 0    Avery Bradley     0.0       PG  25.0    6-2              Texas  7730337.0
# 1      Jae Crowder    99.0       SF  25.0    6-6          Marquette  6796117.0
# 2     John Holland    30.0       SG  27.0    6-5  Boston University        NaN
# 3      R.J. Hunter    28.0       SG  22.0    6-5      Georgia State  1148640.0
# 4    Jonas Jerebko     8.0       PF  29.0   6-10                NaN  5000000.0
# ..             ...     ...      ...   ...    ...                ...        ...
# 453   Shelvin Mack     8.0       PG  26.0    6-3             Butler  2433333.0
# 454      Raul Neto    25.0       PG  24.0    6-1                NaN   900000.0
# 455   Tibor Pleiss    21.0        C  26.0    7-3                NaN  2900000.0
# 456    Jeff Withey    24.0        C  26.0    7-0             Kansas   947276.0
# 457            NaN     NaN      NaN   NaN    NaN                NaN        NaN
#
# [458 rows x 7 columns]

# %% [markdown]
# ## Dealing with rows

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nba.csv",index_col ="Name")

# retrieving row by loc method
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]


print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object
#
#
#  Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
data.drop(["Avery Bradley", "John Holland", "R.J. Hunter",
							"R.J. Hunter"], inplace = True)

# %%
data
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk   Boston Celtics    41.0        C  25.0    7-0   238.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                  College      Salary
# Name
# Jae Crowder    Marquette   6796117.0
# Jonas Jerebko        NaN   5000000.0
# ...

# %%
df.iloc[200:250]
# Out:
#                         Name              Team  Number Position   Age Height  \
# 200              George Hill    Indiana Pacers     3.0       PG  30.0    6-3
# 201              Jordan Hill    Indiana Pacers    27.0        C  28.0   6-10
# 202             Solomon Hill    Indiana Pacers    44.0       SF  25.0    6-7
# 203                Ty Lawson    Indiana Pacers    10.0       PG  28.0   5-11
# 204              Ian Mahinmi    Indiana Pacers    28.0        C  29.0   6-11
# 205               C.J. Miles    Indiana Pacers     0.0       SF  29.0    6-6
# 206       Glenn Robinson III    Indiana Pacers    40.0       SG  22.0    6-7
# 207           Rodney Stuckey    Indiana Pacers     2.0       PG  30.0    6-5
# 208             Myles Turner    Indiana Pacers    33.0       PF  20.0   6-11
# 209       Shayne Whittington    Indiana Pacers    42.0       PF  25.0   6-11
# 210                Joe Young    Indiana Pacers     1.0       PG  23.0    6-2
# ...

# %%
df.iloc[:]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df[df['Position']=='SF']
# Out:
#                        Name                    Team  Number Position   Age  \
# 1               Jae Crowder          Boston Celtics    99.0       SF  25.0
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 35         Cleanthony Early         New York Knicks    11.0       SF  25.0
# 42             Lance Thomas         New York Knicks    42.0       SF  28.0
# ..                      ...                     ...     ...      ...   ...
# 428         Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 432        Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 448          Gordon Hayward               Utah Jazz    20.0       SF  26.0
# 450              Joe Ingles               Utah Jazz     2.0       SF  28.0
# 451           Chris Johnson               Utah Jazz    23.0       SF  26.0
#
#     Height  Weight        College      Salary
# ...

# %%
df[df['Position']=='SF'].count()
# Out:
# Name        85
# Team        85
# Number      85
# Position    85
# Age         85
# Height      85
# Weight      85
# College     71
# Salary      84
# dtype: int64

# %% [markdown]
# ## ILOC & LOC

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nba.csv")
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
first_value=data.iloc[1]
first_value
# Out:
# Name           Jae Crowder
# Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: 1, dtype: object

# %%
data.loc[1]
# Out:
# Name           Jae Crowder
# Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: 1, dtype: object

# %%
data.iloc[0:4]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nba.csv", index_col ="Name")
rows = df.loc[["John Holland", "Jonas Jerebko"]]
print(rows)
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# John Holland   Boston University        NaN
# Jonas Jerebko                NaN  5000000.0

# %%
row1=data.iloc[[5,6,7,8]]

# %%
row1
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
#
#       College      Salary
# 5         NaN  12000000.0
# 6         LSU   1170960.0
# 7     Gonzaga   2165160.0
# 8  Louisville   1824360.0

# %%
row2=data.loc[4:8]

# %%
row2
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
first=df.loc[["John Holland", "Jonas Jerebko"],["Number","Age","Height","Salary"]]
print(first)
# select 2 rows and 4 column
# Out:
#                Number   Age Height     Salary
# Name
# John Holland     30.0  27.0    6-5        NaN
# Jonas Jerebko     8.0  29.0   6-10  5000000.0
#                Number   Age Height     Salary
# Name
# John Holland     30.0  27.0    6-5        NaN
# Jonas Jerebko     8.0  29.0   6-10  5000000.0

# %%
# select all rows and few columns
second=df.loc[:,["Number","Age","Height","Salary"]]
print(second)
# Out:
#                Number   Age Height     Salary
# Name
# Avery Bradley     0.0  25.0    6-2  7730337.0
# Jae Crowder      99.0  25.0    6-6  6796117.0
# John Holland     30.0  27.0    6-5        NaN
# R.J. Hunter      28.0  22.0    6-5  1148640.0
# Jonas Jerebko     8.0  29.0   6-10  5000000.0
# ...               ...   ...    ...        ...
# Shelvin Mack      8.0  26.0    6-3  2433333.0
# Raul Neto        25.0  24.0    6-1   900000.0
# Tibor Pleiss     21.0  26.0    7-3  2900000.0
# Jeff Withey      24.0  26.0    7-0   947276.0
# NaN               NaN   NaN    NaN        NaN
#
# [458 rows x 4 columns]

# %%
data.iloc[:5,1:4]
# when we know exact rows and column that time we will use this function
# Out:
#              Team  Number Position
# 0  Boston Celtics     0.0       PG
# 1  Boston Celtics    99.0       SF
# 2  Boston Celtics    30.0       SG
# 3  Boston Celtics    28.0       SG
# 4  Boston Celtics     8.0       PF

# %%
# select all rows
# and second to fourth column
data[data.columns[1:4]]
# Out:
#                Team  Number Position
# 0    Boston Celtics     0.0       PG
# 1    Boston Celtics    99.0       SF
# 2    Boston Celtics    30.0       SG
# 3    Boston Celtics    28.0       SG
# 4    Boston Celtics     8.0       PF
# ..              ...     ...      ...
# 453       Utah Jazz     8.0       PG
# 454       Utah Jazz    25.0       PG
# 455       Utah Jazz    21.0        C
# 456       Utah Jazz    24.0        C
# 457             NaN     NaN      NaN
#
# [458 rows x 3 columns]

# %% [markdown]
# ## Manupulating Data

# %%
import pandas as pd
data={'Name':["Sushant","Monika","Vijay","Vishal"],'Qualification':['B.E','BSC','Btech','Mtech'],'Salary':[20000,40000,15000,50000]}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name Qualification  Salary
# 0  Sushant           B.E   20000
# 1   Monika           BSC   40000
# 2    Vijay         Btech   15000
# 3   Vishal         Mtech   50000

# %%
# Add new column
cities=['Pune','Aurangabad','Beed','Mumbai']
df['Addess']=cities
print(df)
# Out:
#       Name Qualification  Salary      Addess
# 0  Sushant           B.E   20000        Pune
# 1   Monika           BSC   40000  Aurangabad
# 2    Vijay         Btech   15000        Beed
# 3   Vishal         Mtech   50000      Mumbai

# %% [markdown]
# ## Drop Rows/Column

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nba.csv", index_col ="Name")
# drop column
df.drop(["Team", "Weight"],axis=1, inplace = True)
df
# Out:
#                Number Position   Age Height            College     Salary
# Name
# Avery Bradley     0.0       PG  25.0    6-2              Texas  7730337.0
# Jae Crowder      99.0       SF  25.0    6-6          Marquette  6796117.0
# John Holland     30.0       SG  27.0    6-5  Boston University        NaN
# R.J. Hunter      28.0       SG  22.0    6-5      Georgia State  1148640.0
# Jonas Jerebko     8.0       PF  29.0   6-10                NaN  5000000.0
# ...               ...      ...   ...    ...                ...        ...
# Shelvin Mack      8.0       PG  26.0    6-3             Butler  2433333.0
# Raul Neto        25.0       PG  24.0    6-1                NaN   900000.0
# Tibor Pleiss     21.0        C  26.0    7-3                NaN  2900000.0
# Jeff Withey      24.0        C  26.0    7-0             Kansas   947276.0
# NaN               NaN      NaN   NaN    NaN                NaN        NaN
#
# [458 rows x 6 columns]

# %%
# drop rows
df.drop(["Avery Bradley", "John Holland", "R.J. Hunter"],axis=0, inplace = True)
df
# Out:
#                Number Position   Age Height    College      Salary
# Name
# Jae Crowder      99.0       SF  25.0    6-6  Marquette   6796117.0
# Jonas Jerebko     8.0       PF  29.0   6-10        NaN   5000000.0
# Amir Johnson     90.0       PF  29.0    6-9        NaN  12000000.0
# Jordan Mickey    55.0       PF  21.0    6-8        LSU   1170960.0
# Kelly Olynyk     41.0        C  25.0    7-0    Gonzaga   2165160.0
# ...               ...      ...   ...    ...        ...         ...
# Shelvin Mack      8.0       PG  26.0    6-3     Butler   2433333.0
# Raul Neto        25.0       PG  24.0    6-1        NaN    900000.0
# Tibor Pleiss     21.0        C  26.0    7-3        NaN   2900000.0
# Jeff Withey      24.0        C  26.0    7-0     Kansas    947276.0
# NaN               NaN      NaN   NaN    NaN        NaN         NaN
#
# [455 rows x 6 columns]
