# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushant6862/Jeremy-Howard-Squadron-/blob/main/Capstone_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing pandas module
import pandas as pd

# making data frame
data= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/customer_supermarket.csv",error_bad_lines=False, sep='\t')

# calling head() method
data.head()
# Out:
# <ipython-input-15-db883e7d4f6c>:5: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/customer_supermarket.csv",error_bad_lines=False, sep='\t')
#    Unnamed: 0 BasketID      BasketDate  Sale  CustomerID CustomerCountry  \
# 0           0   536365  01/12/10 08:26  2,55     17850.0  United Kingdom
# 1           1   536365  01/12/10 08:26  3,39     17850.0  United Kingdom
# 2           2   536365  01/12/10 08:26  2,75     17850.0  United Kingdom
# 3           3   536365  01/12/10 08:26  3,39     17850.0  United Kingdom
# 4           4   536365  01/12/10 08:26  3,39     17850.0  United Kingdom
#
#    ProdID                            ProdDescr  Qta
# 0  85123A   WHITE HANGING HEART T-LIGHT HOLDER  6.0
# 1   71053                  WHITE METAL LANTERN  6.0
# 2  84406B       CREAM CUPID HEARTS COAT HANGER  8.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139160 entries, 0 to 139159
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       139160 non-null  int64
#  1   BasketID         139160 non-null  object
#  2   BasketDate       139160 non-null  object
#  3   Sale             139160 non-null  object
#  4   CustomerID       114772 non-null  float64
#  5   CustomerCountry  139160 non-null  object
#  6   ProdID           139160 non-null  object
#  7   ProdDescr        138822 non-null  object
#  8   Qta              139159 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 9.6+ MB

# %%
data.describe()
# Out:
#           CustomerID            Qta
# count  114772.000000  139159.000000
# mean    15284.775381      10.357016
# std      1731.802027     286.363913
# min     12346.000000  -74215.000000
# 25%     13838.000000       1.000000
# 50%     15182.000000       4.000000
# 75%     16842.000000      12.000000
# max     18283.000000   74215.000000

# %%
data.tail(5)
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry ProdID  \
# 165013   550750  20/04/11 11:45  7,95     13632.0  United Kingdom  82484
# 165014   550750  20/04/11 11:45  2,95     13632.0  United Kingdom  22457
# 165015   550750  20/04/11 11:45  1,25     13632.0  United Kingdom  84836
# 165016   550750  20/04/11 11:45  5,95     13632.0  United Kingdom  22427
# 165017   550750  20/04/11 11:45  1,25     13632.0  United Kingdom  21889
#
#                                 ProdDescr   Qta
# 165013  WOOD BLACK BOARD ANT WHITE FINISH   2.0
# 165014    NATURAL SLATE HEART CHALKBOARD    6.0
# 165015        ZINC METAL HEART DECORATION  12.0
# 165016            ENAMEL FLOWER JUG CREAM   3.0
# 165017                   WOODEN BOX OF DO   NaN

# %%
data.iloc[0:50]
# Out:
#    BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0    536365  01/12/10 08:26  2,55     17850.0  United Kingdom  85123A
# 1    536365  01/12/10 08:26  3,39     17850.0  United Kingdom   71053
# 2    536365  01/12/10 08:26  2,75     17850.0  United Kingdom  84406B
# 3    536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029G
# 4    536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029E
# 5    536365  01/12/10 08:26  7,65     17850.0  United Kingdom   22752
# 6    536365  01/12/10 08:26  4,25     17850.0  United Kingdom   21730
# 7    536366  01/12/10 08:28  1,85     17850.0  United Kingdom   22633
# 8    536366  01/12/10 08:28  1,85     17850.0  United Kingdom   22632
# 9    536368  01/12/10 08:34  4,25     13047.0  United Kingdom   22960
# 10   536368  01/12/10 08:34  4,95     13047.0  United Kingdom   22913
# 11   536368  01/12/10 08:34  4,95     13047.0  United Kingdom   22912
# ...

# %%
data.loc[2]
# Out:
# BasketID                                   536365
# BasketDate                         01/12/10 08:26
# Sale                                         2,75
# CustomerID                                17850.0
# CustomerCountry                    United Kingdom
# ProdID                                     84406B
# ProdDescr          CREAM CUPID HEARTS COAT HANGER
# Qta                                           8.0
# Name: 2, dtype: object

# %%
first=data.loc[:,["BasketID", "Sale","CustomerID","ProdID"]]
first
# Out:
#        BasketID  Sale  CustomerID  ProdID
# 0        536365  2,55       17850  85123A
# 1        536365  3,39       17850   71053
# 2        536365  2,75       17850  84406B
# 3        536365  3,39       17850  84029G
# 4        536365  3,39       17850  84029E
# ...         ...   ...         ...     ...
# 165013   550750  7,95       13632   82484
# 165014   550750  2,95       13632   22457
# 165015   550750  1,25       13632   84836
# 165016   550750  5,95       13632   22427
# 165017   550750  1,25       13632   21889
#
# [139160 rows x 4 columns]

# %%
import numpy as np

# %%
data.drop_duplicates()
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365  01/12/10 08:26  2,55     17850.0  United Kingdom  85123A
# 1        536365  01/12/10 08:26  3,39     17850.0  United Kingdom   71053
# 2        536365  01/12/10 08:26  2,75     17850.0  United Kingdom  84406B
# 3        536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029G
# 4        536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029E
# ...         ...             ...   ...         ...             ...     ...
# 165013   550750  20/04/11 11:45  7,95     13632.0  United Kingdom   82484
# 165014   550750  20/04/11 11:45  2,95     13632.0  United Kingdom   22457
# 165015   550750  20/04/11 11:45  1,25     13632.0  United Kingdom   84836
# 165016   550750  20/04/11 11:45  5,95     13632.0  United Kingdom   22427
# 165017   550750  20/04/11 11:45  1,25     13632.0  United Kingdom   21889
#
#                                   ProdDescr   Qta
# ...

# %%
data.loc[:, ~data.columns.duplicated()]
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365  01/12/10 08:26  2,55     17850.0  United Kingdom  85123A
# 1        536365  01/12/10 08:26  3,39     17850.0  United Kingdom   71053
# 2        536365  01/12/10 08:26  2,75     17850.0  United Kingdom  84406B
# 3        536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029G
# 4        536365  01/12/10 08:26  3,39     17850.0  United Kingdom  84029E
# ...         ...             ...   ...         ...             ...     ...
# 165013   550750  20/04/11 11:45  7,95     13632.0  United Kingdom   82484
# 165014   550750  20/04/11 11:45  2,95     13632.0  United Kingdom   22457
# 165015   550750  20/04/11 11:45  1,25     13632.0  United Kingdom   84836
# 165016   550750  20/04/11 11:45  5,95     13632.0  United Kingdom   22427
# 165017   550750  20/04/11 11:45  1,25     13632.0  United Kingdom   21889
#
#                                   ProdDescr   Qta
# ...

# %%
 data.fillna(0)
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365  01/12/10 08:26  2,55       17850  United Kingdom  85123A
# 1        536365  01/12/10 08:26  3,39       17850  United Kingdom   71053
# 2        536365  01/12/10 08:26  2,75       17850  United Kingdom  84406B
# 3        536365  01/12/10 08:26  3,39       17850  United Kingdom  84029G
# 4        536365  01/12/10 08:26  3,39       17850  United Kingdom  84029E
# ...         ...             ...   ...         ...             ...     ...
# 165013   550750  20/04/11 11:45  7,95       13632  United Kingdom   82484
# 165014   550750  20/04/11 11:45  2,95       13632  United Kingdom   22457
# 165015   550750  20/04/11 11:45  1,25       13632  United Kingdom   84836
# 165016   550750  20/04/11 11:45  5,95       13632  United Kingdom   22427
# 165017   550750  20/04/11 11:45  1,25       13632  United Kingdom   21889
#
#                                   ProdDescr   Qta
# ...

# %%
data['CustomerID'] = data['CustomerID']. astype(int)
data
# Out:
#        BasketID      BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365  01/12/10 08:26  2,55       17850  United Kingdom  85123A
# 1        536365  01/12/10 08:26  3,39       17850  United Kingdom   71053
# 2        536365  01/12/10 08:26  2,75       17850  United Kingdom  84406B
# 3        536365  01/12/10 08:26  3,39       17850  United Kingdom  84029G
# 4        536365  01/12/10 08:26  3,39       17850  United Kingdom  84029E
# ...         ...             ...   ...         ...             ...     ...
# 165013   550750  20/04/11 11:45  7,95       13632  United Kingdom   82484
# 165014   550750  20/04/11 11:45  2,95       13632  United Kingdom   22457
# 165015   550750  20/04/11 11:45  1,25       13632  United Kingdom   84836
# 165016   550750  20/04/11 11:45  5,95       13632  United Kingdom   22427
# 165017   550750  20/04/11 11:45  1,25       13632  United Kingdom   21889
#
#                                   ProdDescr   Qta
# ...

# %%
df['BasketDate']=pd.to_datetime(df['BasketDate'], format='%d/%m/%y %H:%M')
df
# Out:
#        BasketID          BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365 2010-12-01 08:26:00  2,55     17850.0  United Kingdom  85123A
# 1        536365 2010-12-01 08:26:00  3,39     17850.0  United Kingdom   71053
# 2        536365 2010-12-01 08:26:00  2,75     17850.0  United Kingdom  84406B
# 3        536365 2010-12-01 08:26:00  3,39     17850.0  United Kingdom  84029G
# 4        536365 2010-12-01 08:26:00  3,39     17850.0  United Kingdom  84029E
# ...         ...                 ...   ...         ...             ...     ...
# 165013   550750 2011-04-20 11:45:00  7,95     13632.0  United Kingdom   82484
# 165014   550750 2011-04-20 11:45:00  2,95     13632.0  United Kingdom   22457
# 165015   550750 2011-04-20 11:45:00  1,25     13632.0  United Kingdom   84836
# 165016   550750 2011-04-20 11:45:00  5,95     13632.0  United Kingdom   22427
# 165017   550750 2011-04-20 11:45:00  1,25     13632.0  United Kingdom   21889
#
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 165013    False
# 165014    False
# 165015    False
# 165016    False
# 165017    False
# Length: 139160, dtype: bool

# %%
df.describe()
# Out:
#           CustomerID            Qta
# count  114772.000000  139159.000000
# mean    15284.775381      10.357016
# std      1731.802027     286.363913
# min     12346.000000  -74215.000000
# 25%     13838.000000       1.000000
# 50%     15182.000000       4.000000
# 75%     16842.000000      12.000000
# max     18283.000000   74215.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
plt.hist(df['Sale'], bins=20, color='pink',edgecolor='red')
plt.title('Sale Distribution')
plt.xlabel('Sale')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df['Qta'], color='purple', shade=True)
plt.title('Qta Density Plot')
plt.xlabel('Qta')
plt.show()
# Out:
# <ipython-input-16-c764a2a17327>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Qta'], color='purple', shade=True)

# %%
df.CustomerCountry.value_counts()[:10].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ##### To Find RFM analysis

# %%
import pandas as pd
data['BasketDate'] = pd.to_datetime(data['BasketDate'])
data
# Out:
#        BasketID          BasketDate  Sale  CustomerID CustomerCountry  ProdID  \
# 0        536365 2010-01-12 08:26:00  2,55     17850.0  United Kingdom  85123A
# 1        536365 2010-01-12 08:26:00  3,39     17850.0  United Kingdom   71053
# 2        536365 2010-01-12 08:26:00  2,75     17850.0  United Kingdom  84406B
# 3        536365 2010-01-12 08:26:00  3,39     17850.0  United Kingdom  84029G
# 4        536365 2010-01-12 08:26:00  3,39     17850.0  United Kingdom  84029E
# ...         ...                 ...   ...         ...             ...     ...
# 165013   550750 2011-04-20 11:45:00  7,95     13632.0  United Kingdom   82484
# 165014   550750 2011-04-20 11:45:00  2,95     13632.0  United Kingdom   22457
# 165015   550750 2011-04-20 11:45:00  1,25     13632.0  United Kingdom   84836
# 165016   550750 2011-04-20 11:45:00  5,95     13632.0  United Kingdom   22427
# 165017   550750 2011-04-20 11:45:00  1,25     13632.0  United Kingdom   21889
#
# ...

# %%
df['BasketDate'] = pd.to_datetime(df['BasketDate'])
min_date = df['BasketDate'].min()
max_date = df['BasketDate'].max()
print("Date Range - From:", min_date, "To:", max_date)
# Out:
# Date Range - From: 2010-01-12 08:26:00 To: 2011-12-04 17:12:00

# %%
df['BasketDate'] = pd.to_datetime(df['BasketDate'])
max_date = df['BasketDate'].max()
print("Maximum Date (Most Recent):", max_date)
# Out:
# Maximum Date (Most Recent): 2011-12-04 17:12:00

# %%
max_date_data = df[df['BasketDate'] == max_date]
print("Data for Maximum Date (Most Recent):\n", max_date_data)
df
# Out:
# Data for Maximum Date (Most Recent):
#         BasketID          BasketDate   Sale  CustomerID CustomerCountry  \
# 154415   549910 2011-12-04 17:12:00   0,95     16697.0  United Kingdom
# 154416   549910 2011-12-04 17:12:00   1,95     16697.0  United Kingdom
# 154417   549910 2011-12-04 17:12:00   4,25     16697.0  United Kingdom
# 154418   549910 2011-12-04 17:12:00   1,65     16697.0  United Kingdom
# 154419   549910 2011-12-04 17:12:00   2,25     16697.0  United Kingdom
# 154420   549910 2011-12-04 17:12:00   2,25     16697.0  United Kingdom
# 154421   549910 2011-12-04 17:12:00   2,25     16697.0  United Kingdom
# 154422   549910 2011-12-04 17:12:00   2,25     16697.0  United Kingdom
# 154423   549910 2011-12-04 17:12:00   8,25     16697.0  United Kingdom
# 154424   549910 2011-12-04 17:12:00   8,25     16697.0  United Kingdom
# 154425   549910 2011-12-04 17:12:00   8,25     16697.0  United Kingdom
# 154426   549910 2011-12-04 17:12:00   2,55     16697.0  United Kingdom
# ...

# %%
df['BasketDate'] = pd.to_datetime(df['BasketDate'])
frequency = df.groupby('CustomerID')['BasketDate'].count()
print(frequency)
frequency.info()
# Out:
# CustomerID
# 12346.0      2
# 12347.0     84
# 12348.0     28
# 12350.0     17
# 12352.0     48
#           ...
# 18272.0     33
# 18273.0      1
# 18277.0      1
# 18280.0     10
# 18283.0    132
# Name: BasketDate, Length: 2425, dtype: int64
# <class 'pandas.core.series.Series'>
# Float64Index: 2425 entries, 12346.0 to 18283.0
# Series name: BasketDate
# Non-Null Count  Dtype
# --------------  -----
# 2425 non-null   int64
# dtypes: int64(1)
# memory usage: 37.9 KB

# %%
df['BasketDate'] = pd.to_datetime(df['BasketDate'])
visit_frequency = df.groupby('CustomerID')['BasketDate'].count()
visit_frequency = visit_frequency.reset_index()
visit_frequency.columns = ['CustomerID', 'VisitFrequency']
print(visit_frequency)
# Out:
#       CustomerID  VisitFrequency
# 0        12346.0               2
# 1        12347.0              84
# 2        12348.0              28
# 3        12350.0              17
# 4        12352.0              48
# ...          ...             ...
# 2420     18272.0              33
# 2421     18273.0               1
# 2422     18277.0               1
# 2423     18280.0              10
# 2424     18283.0             132
#
# [2425 rows x 2 columns]

# %%
grouped = df.groupby('CustomerID').agg({'Qta':'sum','Sale':'sum','Total_Revenue':'sum','BasketDate': lambda v: (max_date - v.max()).days}).reset_index()
print(grouped)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c5973c437a6> in <cell line: 1>()
# ----> 1 grouped = df.groupby('CustomerID').agg({'Qta':'sum','Sale':'sum','Total_Revenue':'sum','BasketDate': lambda v: (max_date - v.max()).days}).reset_index()
#       2 print(grouped)
#
# NameError: name 'df' is not defined
