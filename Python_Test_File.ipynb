# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushant6862/Jeremy-Howard-Squadron-/blob/main/Python_Test_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Python Tutorial 1
# ## Chapter 1
# ### Index 1
#
# ### Image
#  ![image.png](data:image/png;base64,...)

# %%
Print("sushant")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7067c427e678> in <cell line: 1>()
# ----> 1 Print("sushant")
#
# NameError: name 'Print' is not defined

# %%
print("sushant")
# Out:
# sushant

# %%
print("Today is my first class session")
# Out:
# Today is my first class session

# %%
 a=10;
print(a)
# Out:
# 10

# %%
b=20;
print("b")
# Out:
# b

# %%
a=20;
b=30;
c=a+b;
print(c)
# Out:
# 50

# %%
a=10;
b=5;
c=10/5;
print(c)
# Out:
# 2.0

# %%
c=20;
d=4;
e= c*d;
print(e)
# Out:
# 80

# %%
c=20;
type(c)
# Out:
# int

# %%
D=30;
id(D)
# Out:
# 139957035648144

# %%
c=50;
d=10;
e=c/d;
print(e)
# Out:
# 5.0

# %%
a="sushant";
print(len(a))
# Out:
# 7
